# %%
import numpy as np
import pandas as pd
# Warnings
import warnings
warnings.filterwarnings('ignore')
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Create training dataset
Bottle_X = pd.read_csv("Bottle_X.csv")

# %%
# X = Bottle_X[['SensorA_1','SensorA_2','SensorA_3','SensorA_4','X_Axis']].values
# y = Bottle_X['IMU_1'].values

# %%
# # Splitting the dataset into the Training set and Test set

# from sklearn.model_selection import train_test_split
# X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Creating training dataset
X_train = Bottle_X[['SensorA_1','SensorA_2','SensorA_3','SensorA_4','X_Axis']]
Y_train = Bottle_X['IMU_1']

# %%
# plotting corelation matrix
corrMatrix_train = X_train.corr()
sns.heatmap(corrMatrix_train, annot=True)
plt.show()

# %%
# converting to numpy array
X_train = Bottle_X[['SensorA_1','SensorA_2','SensorA_3','SensorA_4','X_Axis']].values
Y_train = Bottle_X['IMU_1'].values

# %%
#Create testing dataset
Gripper = pd.read_csv("Gripper.csv")
X_test = Gripper[['SensorA_1','SensorA_2','SensorA_3','SensorA_4','X_Axis']]
Y_test = Gripper["IMU_X"]

# %%
# plotting corelation matrix
corrMatrix_test = X_test.corr()
sns.heatmap(corrMatrix_test, annot=True)
plt.show()

# %%
# converting to numpy array
X_test = Gripper[['SensorA_1','SensorA_2','SensorA_3','SensorA_4','X_Axis']].values
Y_test = Gripper["IMU_X"].values

# %%
X_train.shape
# Out:
# (1246, 5)

# %%
# X_train = X_train.reshape((-1,1))
Y_train = Y_train.reshape((-1,1))
# X_test = X_test.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

# %%
# finding shapes
X_train.shape,Y_train.shape,X_test.shape,Y_test.shape
# Out:
# ((1246, 5), (1246, 1), (312, 5), (312, 1))

# %%
# Feature scaling
from sklearn import preprocessing
scaler =  preprocessing.Normalizer()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.3893909 ,  0.53070211,  0.11304897,  0.74423905, -0.00762632],
#        [ 0.85057457,  0.31603918,  0.08973952,  0.40187698,  0.08416564],
#        [ 0.3474463 ,  0.54685026,  0.14199979,  0.74323294, -0.08761689],
#        ...,
#        [ 0.70672045,  0.42926723,  0.12040422,  0.54705398,  0.05010611],
#        [ 0.4008719 ,  0.51988075,  0.11587703,  0.7453712 , -0.00447402],
#        [ 0.348066  ,  0.54479895,  0.14225306,  0.74455857, -0.08625983]])

# %%
# # Multiple Linear Regression
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# import os
# import warnings
# warnings.filterwarnings("ignore")
# # Importing the libraries
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# from sklearn.metrics import mean_squared_error,r2_score
# from sklearn.model_selection import KFold
# from sklearn.model_selection import cross_val_score, cross_val_predict
# from sklearn import metrics
# from sklearn.model_selection import train_test_split
# import bisect
# from sklearn.model_selection import cross_val_score
# from sklearn.metrics import mean_squared_error
# from sklearn import metrics
# from sklearn import linear_model
# #     print('LinearRegression')
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.svm import SVR
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import ShuffleSplit
# from sklearn.model_selection import cross_val_predict
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# from sklearn.metrics import mean_squared_error,r2_score
# from sklearn.model_selection import KFold
# from sklearn.model_selection import cross_val_score, cross_val_predict
# from sklearn import metrics
# from sklearn.model_selection import train_test_split
# from sklearn import metrics

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()
model = regressor.fit(X_train,Y_train)
y_pred = model.predict(X_test)

# %%
# # decision tree
# from sklearn.tree import DecisionTreeRegressor
# regressor = DecisionTreeRegressor()
# model = regressor.fit(X_train,Y_train)
# y_pred = model.predict(X_test)

# %%
# # linear regression
# from sklearn import linear_model
# regressor = linear_model.LinearRegression()
# model = regressor.fit(X_train,Y_train)
# y_pred = model.predict(X_test)

# %%
# # svm
# from sklearn.svm import SVR
# regressor = SVR(kernel = 'rbf')
# model = regressor.fit(X_train,Y_train)
# y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score,accuracy_score
from math import sqrt

print(r2_score(Y_test,y_pred))
# print(sqrt(mean_squared_error(Y_test, y_pred)))
# Out:
# 0.994922214680257

# %%
model.score(X_test, Y_test)
# Out:
# -22.853087386714254

# %%
y_pred_Bottle_X = pd.DataFrame(y_pred)

# %%
# y_pred_Bottle_X.to_csv("y_pred_Bottle_X.csv")
